# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bhphoto_df = pd.read_csv("../data/processed/raw_bhphotovideo.csv")
bhphoto_df.head()
# Out:
#                                                 Name  \
# 0  ASUS 13.3" Zenbook S 13 OLED Laptop (Basalt Gray)
# 1  ASUS 15.6" Vivobook S 15 OLED Laptop (Midnight...
# 2            ASUS 15.6" Vivobook Laptop (Quiet Blue)
# 3  ASUS 16" ProArt StudioBook Pro 16 OLED Multi-T...
# 4    Lenovo 15.6" V15 G4 IAN Laptop (Business Black)
#
#            Operating-System                         Processor  \
# 0            Windows 11 Pro    Intel Core i7-1355U (13th Gen)
# 1           Windows 11 Home   Intel Core i9-13900H (13th Gen)
# 2           Windows 11 Home                 AMD Ryzen 7 7730U
# 3            Windows 11 Pro  Intel Core i9-13980HX (13th Gen)
# 4  Windows 11 Home (64-Bit)                        Intel N100
#
#                                                  GPU Total-Installed-Memory  \
# 0                                     Intel Iris Xe                   32 GB
# 1                                     Intel Iris Xe                   16 GB
# 2                                        AMD Radeon                   16 GB
# 3  NVIDIA RTX 3000 Ada (130 W TGP)  with 8 GB GDD...                  64 GB
# 4                                Intel UHD Graphics                    8 GB
#
#   Display-Size   Resolution Touch-Screen Total-Installed-Capacity  \
# 0        13.3"  2880 x 1800           No                     1 TB
# 1        15.6"  2880 x 1620           No                     1 TB
# 2        15.6"  1920 x 1080           No                     1 TB
# 3          16"  3200 x 2000          Yes                     2 TB
# 4        15.6"  1920 x 1080           No                   128 GB
#
#                                       Inputs/Outputs  ...  \
# 0  1 x USB-A 3.1/3.2 Gen 22 x USB-C (Thunderbolt ...  ...
# 1  1 x USB-A 3.0 / 3.1/3.2 Gen 11 x USB-A 2.01 x ...  ...
# 2  1 x USB-C 3.0 / 3.1/3.2 Gen 1 / Supports Power...  ...
# 3  2 x USB-A 3.1/3.2 Gen 22 x USB-C (Thunderbolt ...  ...
# 4  1 x USB-C 3.0 / 3.1/3.2 Gen 1 / Supports Video...  ...
#
#              Batery-Chemistry       Capacity Keyboard  \
# 0                         NaN  4-Cell: 63 Wh      NaN
# 1                         NaN  4-Cell: 75 Wh      NaN
# 2                 Lithium-Ion            NaN      NaN
# 3                 Lithium-Ion  4-Cell: 90 Wh      NaN
# 4  Lithium-Ion Polymer (LiPo)          38 Wh      NaN
#
#                    Power-Supply       Operating-Tempurature  \
# 0               65 W with USB-C  -60 to 160 F / -51 to 71 C
# 1  65 W with Barrel/Proprietary   -6 to 109 F / -21 to 43 C
# 2  45 W with Barrel/Proprietary   -6 to 109 F / -21 to 43 C
# 3                           NaN  -60 to 160 F / -51 to 71 C
# 4  65 W with Barrel/Proprietary      41 to 95 F / 5 to 35 C
#
#        Operating-Humidity                                         Dimensions  \
# 0                     95%     11.66 x 8.52 x 0.46" / 29.62 x 21.63 x 1.18 cm
# 1                     95%      14.15 x 9.03 x 0.7" / 35.93 x 22.94 x 1.79 cm
# 2                     95%     14.16 x 9.15 x 0.78" / 35.97 x 23.25 x 1.99 cm
# 3                     95%          14 x 10.7 x 0.94" / 35.6 x 27.1 x 2.39 cm
# 4  8 to 95% (Recommended)  14.14 x 9.28 x 0.78" / 359.16 x 235.71 x 19.81 mm
#
#   Package-Weight Box-Dimension (LxWxH)      Price
# 0       5.895 lb      17.8 x 11.1 x 4"  $1,299.99
# 1       5.905 lb    18.2 x 11.6 x 2.4"    $989.99
# 2       5.515 lb    19.1 x 11.2 x 2.5"    $699.99
# 3        14.9 lb    23.25 x 15.75 x 6"  $2,999.99
# 4            NaN                   NaN    $367.50
#
# [5 rows x 53 columns]

# %%
amazon_df = pd.read_csv("../data/Processed/missing_value_free.csv")
amazon_df.drop(amazon_df.columns[0], axis=1, inplace=True)
amazon_df.head()
# Out:
#   Brand                      CPU Name  CPU Mark          GPU Name  GPU Mark  \
# 0   MSI          Intel Core i7 13620H   26454.0  GeForce RTX 2050    7320.0
# 1  Dell           Intel Core i9 12900   34306.0  GeForce RTX 4060   19560.0
# 2  Dell  Intel Core i5 2310   2.90GHz    3642.0         Intel Arc    4253.0
# 3  Dell           Intel Core i7 1360P   19333.0     Intel Iris Xe    2690.0
# 4  Dell          Intel Core i7 13700H   28003.0   Intel Arc A730M    8274.0
#
#    Monitor   Width  Height      RAM  Storage Amount          OS    Price  \
# 0     15.6  1920.0  1080.0  16384.0       2097152.0  Windows 11  1529.00
# 1     15.6  1366.0   768.0  16384.0       4096000.0  Windows 11  2308.81
# 2     14.0  1920.0  1080.0   8192.0        262144.0  Windows 10   614.99
# 3     16.0  1920.0  1200.0  24576.0       1048576.0  Windows 10  1079.00
# 4     15.6  1920.0  1200.0  32768.0       1048576.0  Windows 10  1907.00
#
#    New Weight
# 0        3.03
# 1        3.64
# 2        1.23
# 3        1.58
# 4        1.92

# %%
newegg_df = pd.read_csv("../data/Processed/filtered_mapped_newegg.csv")
newegg_df.drop(newegg_df.columns[0], axis=1, inplace=True)
newegg_df.head()
# Out:
#     Brand                                        CPU                     GPU  \
# 0  Lenovo    intel core i7 13th gen 1355u (1.70ghz)   intel iris xe graphics
# 1    Acer     intel core i7 13th gen 1355u (1.70ghz)  intel iris xe graphics
# 2     MSI                          amd ryzen 5-7530u         radeon graphics
# 3    Acer             intel celeron n4500 (1.10ghz)       intel uhd graphics
# 4     MSI  intel core i9 13th gen 13950hx (2.20ghz)             rtx 2000 ada
#
#      RAM      Monitor   Resolution       Storage                     OS  \
# 0  16 GB    16 Inches  1920 x 1200       1TB SSD        Windows 11 Home
# 1  16 GB  15.6 Inches    1920x1080     512GB SSD        Windows 11 Home
# 2  16GB     14 Inches    1920x1080     512GB SSD        Windows 11 Home
# 3    4GB  14.0 Inches   1366 x 768     128GB SSD              Chrome OS
# 4   32GB    16 Inches  2560 x 1600  1TB NVMe SSD  Windows 11 Pro 64-bit
#
#       Weight    Price                       CPU Name  \
# 0  4.17 lbs.   699.99            Intel Core i7 1355U
# 1  3.92 lbs.   699.99            Intel Core i7 1355U
# 2  3.75 lbs.   399.00              AMD Ryzen 5 7530U
# 3        NaN   229.99  Intel Celeron N4500   1.10GHz
# 4        NaN  2891.46          Intel Core i9 13950HX
#
#                                      GPU Name  CPU Mark  GPU Mark
# 0                               Intel Iris Xe   15287.0    2690.0
# 1                               Intel Iris Xe   15287.0    2690.0
# 2  Radeon Ryzen 5 4600GE with Radeon Graphics   16506.0    1792.0
# 3                          Intel UHD Graphics    2003.0    1476.0
# 4          RTX 2000 Ada Generation Laptop GPU   44905.0   15597.0

# %%
pd.set_option('display.max_rows', None)

# %%
amz_brands = amazon_df["Brand"].value_counts()
amazon_df["Brand"] = amazon_df["Brand"].apply(lambda x: x.lower())

# %%
brands_less_than_4 = amz_brands[amz_brands < 4].index.tolist()
amazon_df["Brand"] = amazon_df["Brand"].replace(brands_less_than_4, "other")
amazon_df["Brand"] = amazon_df["Brand"].replace("rokc", "other")
amazon_df["Brand"].value_counts()
# Out:
# dell              1461
# hp                 615
# lenovo             547
# acer               442
# asus               411
# msi                239
# lg                  68
# other               49
# samsung             41
# microsoft           28
# panasonic           24
# gigabyte            22
# best notebooks      12
# apple                9
# Name: Brand, dtype: int64

# %%
nwg_brands = newegg_df["Brand"].value_counts()
newegg_df["Brand"] = newegg_df["Brand"].apply(lambda x: x.lower())
brands_less_than_4 = nwg_brands[nwg_brands < 7].index.tolist()
newegg_df["Brand"] = newegg_df["Brand"].replace(brands_less_than_4, "other")
newegg_df["Brand"].value_counts()
# Out:
# lenovo       1143
# hp           1049
# dell          614
# asus          390
# acer          301
# msi           291
# microsoft     104
# lg             44
# other          43
# samsung        36
# gigabyte        8
# Name: Brand, dtype: int64

# %%
bhphoto_df["Brand"] = bhphoto_df["Name"].str.split().apply(lambda x: x[0])
bhphoto_df = bhphoto_df.drop("Name", axis=1)

# %%
bhp_brands = bhphoto_df["Brand"].value_counts()
bhphoto_df["Brand"] = bhphoto_df["Brand"].apply(lambda x: x.lower())
brands_less_than_4 = bhp_brands[bhp_brands <= 4].index.tolist()
bhphoto_df["Brand"] = bhphoto_df["Brand"].replace(brands_less_than_4, "other")
bhphoto_df["Brand"].value_counts()
# Out:
# apple        349
# hp           313
# lenovo       302
# dell         155
# microsoft     80
# lg            61
# msi           29
# acer          27
# asus          25
# panasonic     24
# samsung       21
# razer         16
# gigabyte      11
# other          7
# Name: Brand, dtype: int64

# %%
bhp_counts = bhphoto_df["Brand"].value_counts(ascending=True)
nwg_counts = newegg_df["Brand"].value_counts(ascending=True)
amz_counts = amazon_df["Brand"].value_counts(ascending=True)

common_labels = set(bhp_counts.index) & set(nwg_counts.index) & set(amz_counts.index)
common_labels = list(common_labels)
colors = [plt.cm.Paired.colors[i % len(plt.cm.Paired.colors)] for i, label in enumerate(common_labels)]

fig, axes = plt.subplots(1, 3, figsize=(24, 8), facecolor='white')

# Bhphotovideo.com
axes[0].pie(bhp_counts, labels=bhp_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 4 else '', startangle=90, colors=[colors[common_labels.index(label)] if label in common_labels else 'gray' for label in bhp_counts.index])
axes[0].set_title('Bhphotovideo.com', fontweight='bold')

# Newegg.com
axes[1].pie(nwg_counts, labels=nwg_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 4 else '', startangle=90, colors=[colors[common_labels.index(label)] if label in common_labels else 'gray' for label in nwg_counts.index])
axes[1].set_title('Newegg.com', fontweight='bold')

# Amazon.com
axes[2].pie(amz_counts, labels=amz_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 4 else '', startangle=90, colors=[colors[common_labels.index(label)] if label in common_labels else 'gray' for label in amz_counts.index])
axes[2].set_title('Amazon.com', fontweight='bold')

# Tiêu đề chung cho figure
plt.suptitle('Comparison of Brand Distribution Across Platforms', fontsize=20, fontweight='bold')

# Hiển thị biểu đồ
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# combine
plt.figure(figsize=(8,8), facecolor='white')
combined_counts = bhp_counts.add(nwg_counts, fill_value=0).add(amz_counts, fill_value=0).sort_values(ascending=True)
combined_colors = [colors[common_labels.index(label)] if label in common_labels else 'gray' for label in combined_counts.index]
plt.pie(combined_counts, labels=combined_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 3 else '', startangle=90, colors=combined_colors)
plt.title('Combined of 3 Platforms', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# ## Merge Data of 3 Platforms
#
# |Colum|Dtype|Example|
# |-|-|-|
# |Brand|object|apple, dell, lenovo, hp...|
# |CPU Brand|object|intel, amd...|
# |GPU Brand|object|intel, geforce...|
# |CPU Mark|float64|2685.0, 15846.0|
# |GPU Mark|float64||
# |Monitor|float64|14.0, 15.6...|
# |Width|int32|1920,...|
# |Height|int32||
# |RAM|int32|4,8,64... `GB`|
# |Storage Amount|int32|`GB`|
# |OS|object|Windows 11, Windows 10,...|
# |Weight|float64|1.64,..`kg`|
# |Price|float64|`target`|

# %%
amz_df = amazon_df
nwg_df = newegg_df
bhp_df = bhphoto_df

# %%
amz_df.drop_duplicates(inplace=True)
amz_df["Price"].describe()
# Out:
# count    3828.00000
# mean     1171.52372
# std       751.91595
# min        99.00000
# 25%       619.00000
# 50%      1019.00000
# 75%      1549.00000
# max      6599.00000
# Name: Price, dtype: float64

# %%
nwg_df.drop_duplicates(inplace=True)
nwg_df["Price"].describe()
# Out:
# count    3891.000000
# mean     1053.603673
# std       685.057361
# min        12.000000
# 25%       619.990000
# 50%       887.090000
# 75%      1279.990000
# max      8999.990000
# Name: Price, dtype: float64

# %% [markdown]
# #### Handle data of Amazon.com

# %%
amz_df.isna().sum()
# Out:
# Brand             0
# CPU Name          0
# CPU Mark          0
# GPU Name          0
# GPU Mark          0
# Monitor           0
# Width             0
# Height            0
# RAM               0
# Storage Amount    0
# OS                0
# Price             0
# New Weight        0
# dtype: int64

# %%
amz_df["CPU Brand"] = amz_df["CPU Name"].str.split().apply(lambda x: x[0].lower())
amz_df["GPU Brand"] = amz_df["GPU Name"].str.split().apply(lambda x: x[0].lower())

# %%
amz_df = amz_df[amz_df["Monitor"] > 6]

# %%
amz_df = amz_df[amz_df["Width"] > 1360]

# %%
amz_df["RAM"] = amz_df["RAM"].apply(lambda x: int(x / 1024))

# %%
amz_df.head(2)
# Out:
#   Brand              CPU Name  CPU Mark          GPU Name  GPU Mark  Monitor  \
# 0   msi  Intel Core i7 13620H   26454.0  GeForce RTX 2050    7320.0     15.6
# 1  dell   Intel Core i9 12900   34306.0  GeForce RTX 4060   19560.0     15.6
#
#     Width  Height      RAM  Storage Amount          OS    Price  New Weight  \
# 0  1920.0  1080.0  16384.0       2097152.0  Windows 11  1529.00        3.03
# 1  1366.0   768.0  16384.0       4096000.0  Windows 11  2308.81        3.64
#
#   CPU Brand GPU Brand
# 0     intel   geforce
# 1     intel   geforce

# %%
amz_df.describe()
# Out:
#            CPU Mark      GPU Mark      Monitor        Width       Height  \
# count   3810.000000   3810.000000  3810.000000  3810.000000  3810.000000
# mean   15966.261155   7744.667454    15.286509  1984.866404  1149.198950
# std    10587.718949   7751.915327     1.250364   470.309036   299.900963
# min      101.000000      2.000000     7.000000  1366.000000   600.000000
# 25%     7528.250000   1476.000000    14.000000  1920.000000  1080.000000
# 50%    15287.000000   4253.000000    15.600000  1920.000000  1080.000000
# 75%    23728.000000  12961.000000    16.000000  1920.000000  1200.000000
# max    61425.000000  38874.000000    18.000000  3840.000000  2400.000000
#
#                RAM  Storage Amount        Price   New Weight
# count  3810.000000    3.810000e+03  3810.000000  3810.000000
# mean     21.313123    1.230771e+06  1174.378685     2.237449
# std      27.961293    1.700076e+07   752.292985     1.728970
# min       2.000000    1.000000e+00    99.000000     0.000000
# 25%       8.000000    5.242880e+05   619.000000     1.640000
# 50%      16.000000    5.242880e+05  1025.000000     2.000000
# 75%      32.000000    1.048576e+06  1549.000000     2.550000
# max    1024.000000    1.048576e+09  6599.000000    59.090000
